# %% [markdown]
# # A Foursquare European Trip
#
# ## 1. Business Understanding
#
# *What is the problem that you are trying to solve?*
#
# **Problem**
#
# There are many people who keep saying that the inner cities in Europe basically all look the same: a big square with a cathedral, nearby mostly the same types of restaurants, bars, shops – which mostly belong to a bigger chain; a castle, a big river, the cool trendy quarter, the not so cool run-down quarter, the train station. Thus, a european trip can be boring for tourists.
#
#
# **Idea**
#
# Why not using open data to avoid boring holidays? Why not using e.g. Foursquare data to determine a trip with the "most diverse" cities or city centers in Europe?
#
#
# **Goals**
#
# The goals are:
# * To compare about 70 cities or their city centers in Italy, France, Spain, Portugal
# * To select 3 italian, 3 french, 3 spanish and 1 portugese cities as such so that they are as diverse as possible.
#
#
# **Target Audience**
#
# The results of this analysis might be useful for tourists planning to visit European cities.
#
#
# ## 2. Analytic Approach and Data Requirements
#
# *How can you use data to answer the question?*
#
# *What data do you need to answer the question?*
#
# To conquer this problem we need:
# * A list of cities from Italy (20 cities), France (20), Spain (20), Portugal (10). Please don't feel discriminated right now if you are Portuguese. The list of cities shall be retrieved from Wikipedia
# * The coordinates of each city (which should also roughly be the city center) based on geopy / Nomatim data
# * Latitude / Longitude
# * Access to Foursquare to determine venues of interest
# * For visualization purposes we need the Folium library
#
#
# The data will be processed using Python in a Jupyter environment.
#
#
# A clustering method (most likely k-means) will be used to compare the cities. The algorithm shall  be optimized by using different evaluation methods.

# %% [markdown]
# ## 3. Data Collection
#
# *Where is the data coming from (identify all sources) and how will you get it?*
#
# ### 3.1 Import libraries

# %%
import numpy as np # library to handle data in a vectorized manner
from bs4 import BeautifulSoup # LIbrary to scrape websites

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import geocoder

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### 3.3 Defines cities of interest
# 10 lists with cities of interest, each list with 7 cities, were defined. This was necessary to avoid coordinate retrieval issues with Nominatim.

# %%
cities_italy1 = ("Rome","Milan","Naples","Turin","Palermo","Genoa","Bologna")
cities_italy2 = ("Florence","Bari","Catania","Venice","Verona","Messina","Padua")
cities_italy3 = ("Trieste","Brescia","Taranto","Parma","Prato","Modena","Reggio Calabria")
cities_france1 = ("Paris","Marseille","Lyon","Toulouse","Nice","Nantes","Strasbourg")
cities_france2 = ("Montpellier","Bordeaux","Lille","Rennes","Reims","Le Havre","Saint-Etienne")
cities_france3 = ("Toulon","Grenoble","Dijon","Nimes","Angers","Villeurbanne","Le Mans")
cities_spain1 = ("Madrid","Barcelona","Valencia","Seville","Zaragoza","Malaga","Murcia")
cities_spain2 = ("Palma","Las Palmas de Gran Canaria","Bilbao","Alicante","Cordoba","Valladolid","Vigo")
cities_spain3 = ("Gijon","L'Hospitalet de Llobregat","A Coruna","Vitoria-Gasteiz","Granada","Elche","Oviedo")
cities_portugal = ("Lisbon","Porto","Vila Nova de Gaia","Amadora","Braga","Coimbra","Funchal")

# %% [markdown]
# ### 3.2 Create a dataframe with cities, country and coordinates
#
# Define a function to retrieve coordinates of cities in a subset of cities

# %%
def getCoord(city_subset,country):
    for city in city_subset:
        geolocator = Nominatim(user_agent="europe_explorer")
        location = geolocator.geocode(city)
        latitude = location.latitude
        longitude = location.longitude
        Lat.append(latitude)
        Lon.append(longitude)    
        City.append(city)
        Country.append(country)

# %% [markdown]
# Initialize lists to store city, country, latitude and longitude coordinates.

# %%
Lat = []
Lon = []
City = []
Country = []

# %% [markdown]
# Retrieve coordinate of cities using subsets of cities, to avoid problem with Nominatim.

# %%
getCoord(cities_italy1,"Italy")

# %%
getCoord(cities_italy2,"Italy")

# %%
getCoord(cities_italy3,"Italy")

# %%
getCoord(cities_france1,"France")

# %%
getCoord(cities_france2,"France")

# %%
getCoord(cities_france3,"France")

# %%
getCoord(cities_spain1,"Spain")

# %%
getCoord(cities_spain2,"Spain")

# %%
getCoord(cities_spain3,"Spain")

# %%
getCoord(cities_portugal,"Portugal")

# %% [markdown]
# Create a dataframe out of the lists.

# %%
df = pd.DataFrame(City,columns=['City'])
df['country']=Country
df['Longitude']=Lon
df['Latitude']=Lat

# %% [markdown]
# ## 4. Data Understanding and Data Preparation
#
# *Is the data that you collected representative of the problem to be solved?*
#
# *What additional work is required to manipulate and work with the data?*

# %% [markdown]
# ## 4.1 Create a map showing the cities of interest
#
# Calculate the centroid of all coordinates of the cities of interest to center the map.

# %%
centroid_Lat=sum(Lat)/len(Lat)
centroid_Lon=sum(Lon)/len(Lon)

# %%
map = folium.Map(location=[centroid_Lat,centroid_Lon], zoom_start=4)

# add markers to map
for lat, lng, city, country in zip(df['Latitude'], df['Longitude'], df['City'], df['country']):
    label = '{}, {}'.format(city, country)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map)  

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 4.2 Get venues for each city center
#
# Define radius around city center and limit of venues to get

# %%
radius=2000
LIMIT=100

# %% [markdown]
# Foursquare Credentials

# %%
#hidden

# %% [markdown]
# A function to repeat the process to get venues to all the cities

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['City', 
                  'City Latitude', 
                  'City Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Use function to get nearby venues for all cities

# %%
city_venues = getNearbyVenues(names=df['City'],
                                  latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Rome
# Milan
# Naples
# Turin
# Palermo
# Genoa
# Bologna
# Florence
# Bari
# Catania
# Venice
# Verona
# Messina
# Padua
# Trieste
# Brescia
# Taranto
# Parma
# Prato
# Modena
# Reggio Calabria
# Paris
# Marseille
# Lyon
# Toulouse
# Nice
# Nantes
# Strasbourg
# Montpellier
# Bordeaux
# Lille
# Rennes
# Reims
# Le Havre
# Saint-Etienne
# Toulon
# Grenoble
# Dijon
# Nimes
# Angers
# Villeurbanne
# Le Mans
# Madrid
# Barcelona
# Valencia
# Seville
# Zaragoza
# Malaga
# Murcia
# Palma
# Las Palmas de Gran Canaria
# Bilbao
# Alicante
# Cordoba
# Valladolid
# Vigo
# Gijon
# L'Hospitalet de Llobregat
# A Coruna
# Vitoria-Gasteiz
# Granada
# Elche
# Oviedo
# Lisbon
# Porto
# Vila Nova de Gaia
# Amadora
# Braga
# Coimbra
# Funchal

# %% [markdown]
# Check how many venues were returned for each city

# %%
city_venues.groupby('City').count()
# Out:
#                             City Latitude  City Longitude  Venue  \
# City
# A Coruna                              100             100    100
# Alicante                               16              16     16
# Amadora                                13              13     13
# Angers                                 53              53     53
# Barcelona                             100             100    100
# Bari                                   24              24     24
# Bilbao                                100             100    100
# Bologna                               100             100    100
# Bordeaux                               90              90     90
# Braga                                 100             100    100
# Catania                                61              61     61
# Coimbra                                64              64     64
# Cordoba                                89              89     89
# Dijon                                  46              46     46
# Elche                                  67              67     67
# Florence                              100             100    100
# Funchal                                67              67     67
# Genoa                                 100             100    100
# Gijon                                  57              57     57
# Granada                                49              49     49
# Grenoble                               13              13     13
# L'Hospitalet de Llobregat              56              56     56
# Las Palmas de Gran Canaria             13              13     13
# Le Havre                               34              34     34
# Le Mans                                25              25     25
# Lille                                 100             100    100
# Lisbon                                100             100    100
# Lyon                                   50              50     50
# Madrid                                100             100    100
# Malaga                                100             100    100
# Marseille                              86              86     86
# Messina                                18              18     18
# Milan                                 100             100    100
# Modena                                 75              75     75
# Montpellier                           100             100    100
# Murcia                                 17              17     17
# Nantes                                 58              58     58
# Naples                                 46              46     46
# Nice                                   81              81     81
# Nimes                                  45              45     45
# Oviedo                                  1               1      1
# Padua                                 100             100    100
# Palermo                                21              21     21
# Palma                                 100             100    100
# Paris                                 100             100    100
# Parma                                  69              69     69
# Porto                                 100             100    100
# Prato                                   1               1      1
# Reggio Calabria                        11              11     11
# Reims                                  59              59     59
# Rennes                                 62              62     62
# Rome                                   93              93     93
# Saint-Etienne                          19              19     19
# Seville                               100             100    100
# Strasbourg                             84              84     84
# Toulon                                 22              22     22
# Toulouse                               76              76     76
# Trieste                                62              62     62
# Turin                                 100             100    100
# Valencia                              100             100    100
# Valladolid                            100             100    100
# Venice                                100             100    100
# Verona                                 89              89     89
# Vigo                                    3               3      3
# Vila Nova de Gaia                      34              34     34
# Villeurbanne                            5               5      5
# Vitoria-Gasteiz                        52              52     52
#
#                             Venue Latitude  Venue Longitude  Venue Category
# City
# A Coruna                               100              100             100
# Alicante                                16               16              16
# Amadora                                 13               13              13
# Angers                                  53               53              53
# Barcelona                              100              100             100
# Bari                                    24               24              24
# Bilbao                                 100              100             100
# Bologna                                100              100             100
# Bordeaux                                90               90              90
# Braga                                  100              100             100
# Catania                                 61               61              61
# Coimbra                                 64               64              64
# Cordoba                                 89               89              89
# Dijon                                   46               46              46
# Elche                                   67               67              67
# Florence                               100              100             100
# Funchal                                 67               67              67
# Genoa                                  100              100             100
# Gijon                                   57               57              57
# Granada                                 49               49              49
# Grenoble                                13               13              13
# L'Hospitalet de Llobregat               56               56              56
# Las Palmas de Gran Canaria              13               13              13
# Le Havre                                34               34              34
# Le Mans                                 25               25              25
# Lille                                  100              100             100
# Lisbon                                 100              100             100
# Lyon                                    50               50              50
# Madrid                                 100              100             100
# Malaga                                 100              100             100
# Marseille                               86               86              86
# Messina                                 18               18              18
# Milan                                  100              100             100
# Modena                                  75               75              75
# Montpellier                            100              100             100
# Murcia                                  17               17              17
# Nantes                                  58               58              58
# Naples                                  46               46              46
# Nice                                    81               81              81
# Nimes                                   45               45              45
# Oviedo                                   1                1               1
# Padua                                  100              100             100
# Palermo                                 21               21              21
# Palma                                  100              100             100
# Paris                                  100              100             100
# Parma                                   69               69              69
# Porto                                  100              100             100
# Prato                                    1                1               1
# Reggio Calabria                         11               11              11
# Reims                                   59               59              59
# Rennes                                  62               62              62
# Rome                                    93               93              93
# Saint-Etienne                           19               19              19
# Seville                                100              100             100
# Strasbourg                              84               84              84
# Toulon                                  22               22              22
# Toulouse                                76               76              76
# Trieste                                 62               62              62
# Turin                                  100              100             100
# Valencia                               100              100             100
# Valladolid                             100              100             100
# Venice                                 100              100             100
# Verona                                  89               89              89
# Vigo                                     3                3               3
# Vila Nova de Gaia                       34               34              34
# Villeurbanne                             5                5               5
# Vitoria-Gasteiz                         52               52              52

# %% [markdown]
# ## 4.3 Analyze each city
#
# A dataframe is created which displays the top 10 venues for each city.

# %%
# one hot encoding
cities_onehot = pd.get_dummies(city_venues[['Venue Category']], prefix="", prefix_sep="")

# add city column back to dataframe
cities_onehot['City'] = city_venues['City'] 

# move city column to the first column
fixed_columns = [cities_onehot.columns[-1]] + list(cities_onehot.columns[:-1])
cities_onehot = cities_onehot[fixed_columns]

# Next, let's group rows by city and by taking the mean of the frequency of occurrence of each category
cities_grouped = cities_onehot.groupby('City').mean().reset_index()

# %%
# Let's write a function to sort the venues in descending order.
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# Now let's create the new dataframe and display the top 10 venues for each city.
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['City']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
city_venues_sorted = pd.DataFrame(columns=columns)
city_venues_sorted['City'] = cities_grouped['City']

for ind in np.arange(cities_grouped.shape[0]):
    city_venues_sorted.iloc[ind, 1:] = return_most_common_venues(cities_grouped.iloc[ind, :], num_top_venues)

city_venues_sorted.head()
# Out:
#         City  1st Most Common Venue 2nd Most Common Venue  \
# 0   A Coruna                    Bar      Tapas Restaurant
# 1   Alicante      Accessories Store                   Bar
# 2    Amadora  Portuguese Restaurant            Restaurant
# 3     Angers                    Bar                   Pub
# 4  Barcelona       Tapas Restaurant                 Plaza
#
#   3rd Most Common Venue  4th Most Common Venue 5th Most Common Venue  \
# 0            Restaurant     Spanish Restaurant                   Pub
# 1                 Plaza  Performing Arts Venue                   Pub
# 2           Pizza Place          Metro Station           Supermarket
# 3     French Restaurant                 Lounge        Sandwich Place
# 4                   Bar               Wine Bar          Cocktail Bar
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                 Plaza        Ice Cream Shop                  Café
# 1            Public Art                  Park   Moroccan Restaurant
# 2                   Gym                  Café                Bakery
# 3   Japanese Restaurant    Italian Restaurant          Tram Station
# 4          Dessert Shop           Coffee Shop           Pizza Place
#
#   9th Most Common Venue 10th Most Common Venue
# 0    Seafood Restaurant                Brewery
# 1           Gaming Cafe     Basketball Stadium
# 2            Playground   Fast Food Restaurant
# 3                Bakery              Nightclub
# 4    Spanish Restaurant     Italian Restaurant

# %% [markdown]
# # 5. Modeling
#
# *In what way can the data be visualized to get to the answer that is required?*
#
# ## 5.1 k-means Clustering

# %%
# set number of clusters
kclusters = 10

cities_grouped_clustering = cities_grouped.drop('City', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(cities_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([0, 7, 5, 8, 0, 3, 0, 3, 8, 5, 7, 5, 0, 8, 0, 3, 5, 3, 0, 6, 8, 7,
#        0, 8, 8, 8, 5, 6, 0, 0, 8, 7, 3, 3, 8, 7, 8, 7, 8, 8, 1, 3, 7, 0,
#        8, 3, 5, 2, 6, 8, 8, 3, 6, 0, 8, 6, 8, 6, 3, 0, 0, 3, 3, 9, 5, 4,
#        0], dtype=int32)

# %% [markdown]
# ## 5.2 Add clustering labels to dataframe

# %%
# add clustering labels
city_venues_sorted.insert(0, 'Cluster_Labels', kmeans.labels_)

cities_merged = df

# merge cities_grouped with city df to add latitude/longitude for each city
cities_merged = cities_merged.join(city_venues_sorted.set_index('City'), on='City')

cities_merged.head() # check the last columns!
# Out:
#       City country  Longitude   Latitude  Cluster_Labels  \
# 0     Rome   Italy  12.485338  41.894802             3.0
# 1    Milan   Italy   9.190500  45.466800             3.0
# 2   Naples   Italy  14.248783  40.835934             7.0
# 3    Turin   Italy   7.682489  45.067755             3.0
# 4  Palermo   Italy  13.352443  38.111227             7.0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0    Italian Restaurant         Historic Site                 Plaza
# 1    Italian Restaurant              Boutique                 Hotel
# 2           Pizza Place        Ice Cream Shop                  Café
# 3                  Café        Ice Cream Shop                 Plaza
# 4                 Plaza    Italian Restaurant        History Museum
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0                Temple        History Museum                Museum
# 1                 Plaza           Pizza Place          Cocktail Bar
# 2    Italian Restaurant     Trattoria/Osteria         Historic Site
# 3           Pizza Place    Italian Restaurant                 Hotel
# 4         Historic Site            Restaurant          Cocktail Bar
#
#   7th Most Common Venue 8th Most Common Venue   9th Most Common Venue  \
# 0                 Hotel   Monument / Landmark          Scenic Lookout
# 1        Ice Cream Shop             Bookstore             Coffee Shop
# 2       Harbor / Marina                 Plaza             Pastry Shop
# 3             Bookstore         Historic Site  Piedmontese Restaurant
# 4        Sandwich Place                   Bar                    Café
#
#   10th Most Common Venue
# 0                   Café
# 1    Monument / Landmark
# 2     Seafood Restaurant
# 3               Boutique
# 4                Brewery

# %% [markdown]
# ## 5.3 Display Clustering on Map

# %%
cities_merged=cities_merged.dropna()
cities_merged['Cluster_Labels'] = cities_merged.Cluster_Labels.astype(int)

# create map
map_clusters = folium.Map(location=[centroid_Lat,centroid_Lon], zoom_start=4)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(cities_merged['Latitude'], cities_merged['Longitude'], cities_merged['City'], cities_merged['Cluster_Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 5.4 Explore Clusters
#
# ### 5.4.1 Cluster 0

# %%
cities_merged.loc[cities_merged['Cluster_Labels'] == 0, cities_merged.columns[[0] + [1] + list(range(5, cities_merged.shape[1]))]]
# Out:
#                           City country 1st Most Common Venue  \
# 42                      Madrid   Spain    Spanish Restaurant
# 43                   Barcelona   Spain      Tapas Restaurant
# 44                    Valencia   Spain            Restaurant
# 45                     Seville   Spain      Tapas Restaurant
# 47                      Malaga   Spain    Spanish Restaurant
# 49                       Palma   Spain      Tapas Restaurant
# 50  Las Palmas de Gran Canaria   Spain      Tapas Restaurant
# 51                      Bilbao   Spain    Spanish Restaurant
# 53                     Cordoba   Spain    Spanish Restaurant
# 54                  Valladolid   Spain      Tapas Restaurant
# 56                       Gijon   Spain            Restaurant
# 58                    A Coruna   Spain                   Bar
# 59             Vitoria-Gasteiz   Spain                   Bar
# 61                       Elche   Spain                  Café
#
#    2nd Most Common Venue 3rd Most Common Venue     4th Most Common Venue  \
# 42      Tapas Restaurant                 Hotel                     Plaza
# 43                 Plaza                   Bar                  Wine Bar
# 44                 Hotel    Spanish Restaurant  Mediterranean Restaurant
# 45                 Plaza                 Hotel        Spanish Restaurant
# 47      Tapas Restaurant                  Café                     Plaza
# 49                 Plaza                  Café                     Hotel
# 50     Indian Restaurant                   Gym            Breakfast Spot
# 51            Restaurant      Tapas Restaurant        Seafood Restaurant
# 53                 Hotel                   Bar          Tapas Restaurant
# 54                   Bar    Spanish Restaurant                      Café
# 56    Spanish Restaurant                 Plaza               Pizza Place
# 58      Tapas Restaurant            Restaurant        Spanish Restaurant
# 59                 Plaza    Spanish Restaurant                Restaurant
# 61            Restaurant      Tapas Restaurant               Beer Garden
#
#        5th Most Common Venue     6th Most Common Venue 7th Most Common Venue  \
# 42                    Hostel                 Bookstore            Restaurant
# 43              Cocktail Bar              Dessert Shop           Coffee Shop
# 44                     Plaza               Coffee Shop        Clothing Store
# 45            Ice Cream Shop                      Café            Restaurant
# 47                       Bar                     Hotel             Bookstore
# 49        Spanish Restaurant                Restaurant                   Bar
# 50             Shopping Mall        Spanish Restaurant           Supermarket
# 51                     Plaza                       Bar                  Café
# 53                     Plaza                      Café                Hostel
# 54                     Plaza  Mediterranean Restaurant            Restaurant
# 56  Mediterranean Restaurant                       Pub           Music Venue
# 58                       Pub                     Plaza        Ice Cream Shop
# 59                       Pub        Italian Restaurant      Tapas Restaurant
# 61            Ice Cream Shop        Spanish Restaurant                 Plaza
#
#    8th Most Common Venue          9th Most Common Venue  \
# 42          Gourmet Shop                        Theater
# 43           Pizza Place             Spanish Restaurant
# 44        Ice Cream Shop                   Burger Joint
# 45         Historic Site                            Bar
# 47    Seafood Restaurant       Mediterranean Restaurant
# 49        Ice Cream Shop  Vegetarian / Vegan Restaurant
# 50                  Road                    Snack Place
# 51              Wine Bar                   Cocktail Bar
# 53            Restaurant                 Sandwich Place
# 54          Gourmet Shop                      Nightclub
# 56    Italian Restaurant               Tapas Restaurant
# 58                  Café             Seafood Restaurant
# 59                  Café               Department Store
# 61                   Pub                  Historic Site
#
#       10th Most Common Venue
# 42              Cocktail Bar
# 43        Italian Restaurant
# 44        Italian Restaurant
# 45  Mediterranean Restaurant
# 47                Restaurant
# 49               Coffee Shop
# 50               Coffee Shop
# 51                    Bakery
# 53                   Theater
# 54               Art Gallery
# 56                      Café
# 58                   Brewery
# 59            Breakfast Spot
# 61                   Brewery

# %% [markdown]
# ### 5.4.2 Cluster 1

# %%
cities_merged.loc[cities_merged['Cluster_Labels'] == 1, cities_merged.columns[[0] + [1] + list(range(5, cities_merged.shape[1]))]]
# Out:
#       City country 1st Most Common Venue 2nd Most Common Venue  \
# 62  Oviedo   Spain           Supermarket         Women's Store
#
#          3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 62  Financial or Legal Service           Event Space           Fabric Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 62    Falafel Restaurant        Farmers Market  Fast Food Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 62     Fish & Chips Shop    Fried Chicken Joint

# %% [markdown]
# ### 5.4.3 Cluster 2

# %%
cities_merged.loc[cities_merged['Cluster_Labels'] == 2, cities_merged.columns[[0] + [1] + list(range(5, cities_merged.shape[1]))]]
# Out:
#      City country 1st Most Common Venue 2nd Most Common Venue  \
# 18  Prato   Italy    Italian Restaurant         Women's Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 18     Fish & Chips Shop           Event Space           Fabric Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 18    Falafel Restaurant        Farmers Market  Fast Food Restaurant
#
#          9th Most Common Venue 10th Most Common Venue
# 18  Financial or Legal Service            Fish Market

# %% [markdown]
# ### 5.4.4 Cluster 3

# %%
cities_merged.loc[cities_merged['Cluster_Labels'] == 3, cities_merged.columns[[0] + [1] + list(range(5, cities_merged.shape[1]))]]
# Out:
#         City country 1st Most Common Venue 2nd Most Common Venue  \
# 0       Rome   Italy    Italian Restaurant         Historic Site
# 1      Milan   Italy    Italian Restaurant              Boutique
# 3      Turin   Italy                  Café        Ice Cream Shop
# 5      Genoa   Italy    Italian Restaurant                 Plaza
# 6    Bologna   Italy    Italian Restaurant                 Plaza
# 7   Florence   Italy    Italian Restaurant                 Hotel
# 8       Bari   Italy           Pizza Place                 Hotel
# 10    Venice   Italy    Italian Restaurant                 Hotel
# 11    Verona   Italy    Italian Restaurant           Pizza Place
# 13     Padua   Italy                  Café    Italian Restaurant
# 17     Parma   Italy    Italian Restaurant                  Café
# 19    Modena   Italy                  Café    Italian Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                  Plaza                Temple        History Museum
# 1                  Hotel                 Plaza           Pizza Place
# 3                  Plaza           Pizza Place    Italian Restaurant
# 5                    Pub                  Café                   Bar
# 6                   Café        Ice Cream Shop                 Hotel
# 7         Ice Cream Shop                 Plaza                  Café
# 8                   Café            Restaurant                 Plaza
# 10        Ice Cream Shop                 Plaza                   Bar
# 11                 Hotel                   Bar            Restaurant
# 13                 Plaza           Pizza Place              Wine Bar
# 17        Sandwich Place        Ice Cream Shop            Restaurant
# 19        Ice Cream Shop                 Plaza                 Diner
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                 Museum                 Hotel   Monument / Landmark
# 1           Cocktail Bar        Ice Cream Shop             Bookstore
# 3                  Hotel             Bookstore         Historic Site
# 5          Historic Site        Ice Cream Shop            Restaurant
# 6               Wine Bar        History Museum             Bookstore
# 7             Art Museum        Sandwich Place           Art Gallery
# 8     Italian Restaurant    Seafood Restaurant        Ice Cream Shop
# 10              Wine Bar                  Café            Restaurant
# 11                  Café        Ice Cream Shop         Historic Site
# 13        Ice Cream Shop                   Bar                Bakery
# 17                 Plaza                 Hotel              Wine Bar
# 19               Brewery              Wine Bar                   Pub
#
#      9th Most Common Venue 10th Most Common Venue
# 0           Scenic Lookout                   Café
# 1              Coffee Shop    Monument / Landmark
# 3   Piedmontese Restaurant               Boutique
# 5                    Hotel            Pizza Place
# 6           Sandwich Place       Toy / Game Store
# 7             Cocktail Bar               Boutique
# 8             Burger Joint                   Food
# 10                  Museum           Cocktail Bar
# 11                Boutique                Theater
# 13                     Pub         Sandwich Place
# 17            Cocktail Bar      Trattoria/Osteria
# 19          Sandwich Place    Japanese Restaurant

# %% [markdown]
# ### 5.4.5 Cluster 4

# %%
cities_merged.loc[cities_merged['Cluster_Labels'] == 4, cities_merged.columns[[0] + [1] + list(range(5, cities_merged.shape[1]))]]
# Out:
#             City country 1st Most Common Venue 2nd Most Common Venue  \
# 40  Villeurbanne  France         Women's Store           Art Gallery
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 40           Supermarket                Bakery            Hookah Bar
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 40                  Food           Flower Shop           Fish Market
#
#    9th Most Common Venue 10th Most Common Venue
# 40     Food & Drink Shop           Food Service

# %% [markdown]
# ### 5.4.6 Cluster 5

# %%
cities_merged.loc[cities_merged['Cluster_Labels'] == 5, cities_merged.columns[[0] + [1] + list(range(5, cities_merged.shape[1]))]]
# Out:
#                  City   country  1st Most Common Venue 2nd Most Common Venue  \
# 63             Lisbon  Portugal  Portuguese Restaurant                 Hotel
# 64              Porto  Portugal  Portuguese Restaurant                   Bar
# 65  Vila Nova de Gaia  Portugal                   Café                Bakery
# 66            Amadora  Portugal  Portuguese Restaurant            Restaurant
# 67              Braga  Portugal                    Bar            Restaurant
# 68            Coimbra  Portugal  Portuguese Restaurant                Bakery
# 69            Funchal  Portugal                   Café            Restaurant
#
#     3rd Most Common Venue  4th Most Common Venue 5th Most Common Venue  \
# 63         Ice Cream Shop             Restaurant                   Bar
# 64                  Hotel                   Café                 Plaza
# 65             Restaurant            Coffee Shop      Sushi Restaurant
# 66            Pizza Place          Metro Station           Supermarket
# 67  Portuguese Restaurant                   Café                 Plaza
# 68                  Plaza             Restaurant                   Bar
# 69                  Plaza  Portuguese Restaurant                Bakery
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 63                 Plaza              Wine Bar           Coffee Shop
# 64                Hostel    Italian Restaurant        Breakfast Spot
# 65         Grocery Store             Gastropub    Spanish Restaurant
# 66                   Gym                  Café                Bakery
# 67           Coffee Shop          Burger Joint      Tapas Restaurant
# 68                 Hotel      Tapas Restaurant                  Café
# 69                 Hotel    Seafood Restaurant        Ice Cream Shop
#
#    9th Most Common Venue 10th Most Common Venue
# 63             Gastropub       Tapas Restaurant
# 64            Restaurant         Ice Cream Shop
# 65            Steakhouse            Supermarket
# 66            Playground   Fast Food Restaurant
# 67                Bakery    Japanese Restaurant
# 68             Gastropub            Supermarket
# 69         Historic Site            Coffee Shop

# %% [markdown]
# ### 5.4.7 Cluster 6

# %%
cities_merged.loc[cities_merged['Cluster_Labels'] == 6, cities_merged.columns[[0] + [1] + list(range(5, cities_merged.shape[1]))]]
# Out:
#                City country 1st Most Common Venue 2nd Most Common Venue  \
# 14          Trieste   Italy                 Hotel                  Café
# 20  Reggio Calabria   Italy                 Plaza  Fast Food Restaurant
# 23             Lyon  France                 Plaza                 Hotel
# 34    Saint-Etienne  France                 Plaza             Bookstore
# 35           Toulon  France                 Plaza                 Hotel
# 60          Granada   Spain                 Hotel                  Café
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 14                 Plaza    Italian Restaurant        Ice Cream Shop
# 20                Castle                  Café            Steakhouse
# 23    Italian Restaurant              Wine Bar                  Café
# 34                   Pub     French Restaurant             Multiplex
# 35             Irish Pub           Pizza Place         Train Station
# 60                 Plaza                   Bar      Tapas Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 14                   Bar     Trattoria/Osteria         Historic Site
# 20         Train Station          Burger Joint                Garden
# 23     French Restaurant           Coffee Shop                Resort
# 34        Farmers Market                  Café        Sandwich Place
# 35  Fast Food Restaurant                  Café           Salad Place
# 60    Spanish Restaurant        Scenic Lookout             Nightclub
#
#    9th Most Common Venue 10th Most Common Venue
# 14           Pizza Place            Coffee Shop
# 20     Trattoria/Osteria                  Hotel
# 23                   Pub           Optical Shop
# 34            Steakhouse       Sushi Restaurant
# 35                Lounge             Restaurant
# 60           Coffee Shop         Breakfast Spot

# %% [markdown]
# ### 5.4.8 Cluster 7

# %%
cities_merged.loc[cities_merged['Cluster_Labels'] == 7, cities_merged.columns[[0] + [1] + list(range(5, cities_merged.shape[1]))]]
# Out:
#                          City country     1st Most Common Venue  \
# 2                      Naples   Italy               Pizza Place
# 4                     Palermo   Italy                     Plaza
# 9                     Catania   Italy               Pizza Place
# 12                    Messina   Italy        Italian Restaurant
# 48                     Murcia   Spain          Tapas Restaurant
# 52                   Alicante   Spain         Accessories Store
# 57  L'Hospitalet de Llobregat   Spain  Mediterranean Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue  4th Most Common Venue  \
# 2         Ice Cream Shop                  Café     Italian Restaurant
# 4     Italian Restaurant        History Museum          Historic Site
# 9           Cocktail Bar    Italian Restaurant                  Plaza
# 12          Dessert Shop      Greek Restaurant           Cocktail Bar
# 48                 Plaza           Pizza Place                   Park
# 52                   Bar                 Plaza  Performing Arts Venue
# 57            Restaurant           Pizza Place           Cocktail Bar
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 2      Trattoria/Osteria         Historic Site       Harbor / Marina
# 4             Restaurant          Cocktail Bar        Sandwich Place
# 9        Bed & Breakfast          Dessert Shop                Church
# 12         Movie Theater           Pizza Place                  Café
# 48            Steakhouse            Bagel Shop          Tennis Court
# 52                   Pub            Public Art                  Park
# 57                  Café                   Bar                Bakery
#
#    8th Most Common Venue 9th Most Common Venue    10th Most Common Venue
# 2                  Plaza           Pastry Shop        Seafood Restaurant
# 4                    Bar                  Café                   Brewery
# 9                    Pub            Restaurant                      Café
# 12        Scenic Lookout             Gastropub                   Theater
# 48    Light Rail Station             Nightclub  Mediterranean Restaurant
# 52   Moroccan Restaurant           Gaming Cafe        Basketball Stadium
# 57                 Diner    Spanish Restaurant             Train Station

# %% [markdown]
# ### 5.4.9 Cluster 8

# %%
cities_merged.loc[cities_merged['Cluster_Labels'] == 8, cities_merged.columns[[0] + [1] + list(range(5, cities_merged.shape[1]))]]
# Out:
#            City country 1st Most Common Venue 2nd Most Common Venue  \
# 21        Paris  France     French Restaurant        Ice Cream Shop
# 22    Marseille  France     French Restaurant                 Hotel
# 24     Toulouse  France     French Restaurant                 Plaza
# 25         Nice  France                 Hotel     French Restaurant
# 26       Nantes  France                   Bar     French Restaurant
# 27   Strasbourg  France     French Restaurant                 Plaza
# 28  Montpellier  France     French Restaurant                   Bar
# 29     Bordeaux  France     French Restaurant                 Plaza
# 30        Lille  France     French Restaurant           Coffee Shop
# 31       Rennes  France                   Bar                 Plaza
# 32        Reims  France     French Restaurant                   Bar
# 33     Le Havre  France     French Restaurant                   Bar
# 36     Grenoble  France     French Restaurant                Museum
# 37        Dijon  France     French Restaurant                  Café
# 38        Nimes  France     French Restaurant                   Bar
# 39       Angers  France                   Bar                   Pub
# 41      Le Mans  France                 Plaza     French Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 21                 Plaza           Art Gallery                   Pub
# 22                   Bar                 Plaza                   Pub
# 24              Tea Room                   Bar           Coffee Shop
# 25        Ice Cream Shop  Fast Food Restaurant        Clothing Store
# 26                 Plaza            Restaurant           Pizza Place
# 27                   Bar                Bakery                 Hotel
# 28                  Café                   Pub          Cocktail Bar
# 29           Coffee Shop      Pedestrian Plaza                 Hotel
# 30          Cocktail Bar                   Bar              Creperie
# 31              Creperie           Coffee Shop             Irish Pub
# 32                 Plaza              Wine Bar            Restaurant
# 33                   Pub      Department Store                 Hotel
# 36                  Food                Garden        Soccer Stadium
# 37                 Hotel                 Plaza   Japanese Restaurant
# 38                 Hotel                 Plaza    Italian Restaurant
# 39     French Restaurant                Lounge        Sandwich Place
# 41        Sandwich Place      Department Store           Pizza Place
#
#    6th Most Common Venue 7th Most Common Venue      8th Most Common Venue  \
# 21          Cocktail Bar         Souvenir Shop                        Bar
# 22        Ice Cream Shop           Pizza Place                 Steakhouse
# 24        Ice Cream Shop          Burger Joint                 Restaurant
# 25           Coffee Shop    Italian Restaurant  Middle Eastern Restaurant
# 26      Greek Restaurant     Indian Restaurant                Coffee Shop
# 27   Alsatian Restaurant          Cupcake Shop                    Brewery
# 28                 Plaza           Coffee Shop                   Wine Bar
# 29                  Café         Shopping Mall                     Bistro
# 30                 Plaza          Burger Joint                       Café
# 31         Historic Site                Bakery                        Pub
# 32                Bakery             Gastropub       Fast Food Restaurant
# 33      Sushi Restaurant           Coffee Shop                     Lounge
# 36                 Plaza             Multiplex                        Pub
# 37                   Bar              Wine Bar               Gourmet Shop
# 38           Supermarket           Coffee Shop              Historic Site
# 39   Japanese Restaurant    Italian Restaurant               Tram Station
# 41                Church             Brasserie              Shopping Mall
#
#    9th Most Common Venue  10th Most Common Venue
# 21        Cosmetics Shop                    Park
# 22    Seafood Restaurant                    Café
# 24                 Hotel  Argentinian Restaurant
# 25            Restaurant         Bed & Breakfast
# 26           Salad Place                  Castle
# 27    Italian Restaurant              Restaurant
# 28          Burger Joint             Pizza Place
# 29     Electronics Store                  Bakery
# 30    Italian Restaurant     Japanese Restaurant
# 31                Market       French Restaurant
# 32                 Hotel                  Church
# 33              Beer Bar             Supermarket
# 36           Music Venue            Tram Station
# 37            Art Museum      Italian Restaurant
# 38        Ice Cream Shop          Farmers Market
# 39                Bakery               Nightclub
# 41          Burger Joint                  Bistro

# %% [markdown]
# ### 5.4.10 Cluster 9

# %%
cities_merged.loc[cities_merged['Cluster_Labels'] == 9, cities_merged.columns[[0] + [1] + list(range(5, cities_merged.shape[1]))]]
# Out:
#     City country 1st Most Common Venue 2nd Most Common Venue  \
# 55  Vigo   Spain                  Café           Gaming Cafe
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 55           Coffee Shop         Women's Store     Fish & Chips Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 55    Falafel Restaurant        Farmers Market  Fast Food Restaurant
#
#          9th Most Common Venue 10th Most Common Venue
# 55  Financial or Legal Service            Flower Shop

# %% [markdown]
# ### 5.4.11 Summarize clusters
#
# - Cluster 0 - "Spanish Cluster"
# - Cluster 1 - Oviedo, Spain (1 venue) - excluded
# - Cluster 2 - Prato, Italy (1 venue) - excluded
# - Cluster 3 - "Italian Cluster"
# - Cluster 4 - Villeurbane, France (5 venues) - excluded
# - Cluster 5 - "Portoguese Cluster"
# - Cluster 6 - Cities in Italy, France, Spain
# - Cluster 7 - Cities in Italy and Spain
# - Cluster 8 - "French Cluster"
# - Cluster 9 - Vigo, Spain (3 venues) - excluded

# %% [markdown]
# # 6 Select cities
#
# ## Selection of 3 italian cities
#
# - Select 1 city from cluster 3 ("Italian Cluster") - Rome (first entry)
# - Select 1 city from cluster 6 - Trieste (first italian entry)
# - Select 1 city from cluster 7 - Naples (first italian entry)
#
# ## Selection of the portoguese city
#
# - Select 1 city from cluster 5 ("Portoguese Cluster") - Lisbon
#
# ## Selection of 3 french cities:
#
# - Select 2 cities from cluster 8 ("French Cluster") - Paris (first entry) and Nice
# - Select 1 city from cluster 6 - Lyon (first french entry)
#
# ## Selection of 3 spanish cities
#
# - Select 1 city from cluster 0 ("Spanish Cluster") - Madrid (first entry)
# - Select 1 city from cluster 6 - Granada (first spanish entry)
# - Select 1 city from cluster 7 - Murcia (first spanish entry)
#
# ## Excluded clusters
#
# Clusters 1, 2, 4 and 9 were excluded because they contain only 1 city each with very few venues (between 1 and 5).
#
# ## Show selected cities with their labeling on the map

# %%
cities_selected = ("Rome","Trieste","Naples","Paris","Nice","Lyon","Madrid","Granada","Murcia","Lisbon")
cities_merged_selected = cities_merged.loc[cities_merged['City'].isin(cities_selected)]
cities_merged_selected
# Out:
#        City   country  Longitude   Latitude  Cluster_Labels  \
# 0      Rome     Italy  12.485338  41.894802               3
# 2    Naples     Italy  14.248783  40.835934               7
# 14  Trieste     Italy  13.770656  45.650033               6
# 21    Paris    France   2.351499  48.856610               8
# 23     Lyon    France   4.832011  45.757814               6
# 25     Nice    France   7.268391  43.700936               8
# 42   Madrid     Spain  -3.703582  40.416705               0
# 48   Murcia     Spain  -1.130543  37.992379               7
# 60  Granada     Spain  -3.602193  37.183054               6
# 63   Lisbon  Portugal  -9.136592  38.707751               5
#
#     1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0      Italian Restaurant         Historic Site                 Plaza
# 2             Pizza Place        Ice Cream Shop                  Café
# 14                  Hotel                  Café                 Plaza
# 21      French Restaurant        Ice Cream Shop                 Plaza
# 23                  Plaza                 Hotel    Italian Restaurant
# 25                  Hotel     French Restaurant        Ice Cream Shop
# 42     Spanish Restaurant      Tapas Restaurant                 Hotel
# 48       Tapas Restaurant                 Plaza           Pizza Place
# 60                  Hotel                  Café                 Plaza
# 63  Portuguese Restaurant                 Hotel        Ice Cream Shop
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0                 Temple        History Museum                Museum
# 2     Italian Restaurant     Trattoria/Osteria         Historic Site
# 14    Italian Restaurant        Ice Cream Shop                   Bar
# 21           Art Gallery                   Pub          Cocktail Bar
# 23              Wine Bar                  Café     French Restaurant
# 25  Fast Food Restaurant        Clothing Store           Coffee Shop
# 42                 Plaza                Hostel             Bookstore
# 48                  Park            Steakhouse            Bagel Shop
# 60                   Bar      Tapas Restaurant    Spanish Restaurant
# 63            Restaurant                   Bar                 Plaza
#
#    7th Most Common Venue      8th Most Common Venue 9th Most Common Venue  \
# 0                  Hotel        Monument / Landmark        Scenic Lookout
# 2        Harbor / Marina                      Plaza           Pastry Shop
# 14     Trattoria/Osteria              Historic Site           Pizza Place
# 21         Souvenir Shop                        Bar        Cosmetics Shop
# 23           Coffee Shop                     Resort                   Pub
# 25    Italian Restaurant  Middle Eastern Restaurant            Restaurant
# 42            Restaurant               Gourmet Shop               Theater
# 48          Tennis Court         Light Rail Station             Nightclub
# 60        Scenic Lookout                  Nightclub           Coffee Shop
# 63              Wine Bar                Coffee Shop             Gastropub
#
#       10th Most Common Venue
# 0                       Café
# 2         Seafood Restaurant
# 14               Coffee Shop
# 21                      Park
# 23              Optical Shop
# 25           Bed & Breakfast
# 42              Cocktail Bar
# 48  Mediterranean Restaurant
# 60            Breakfast Spot
# 63          Tapas Restaurant

# %%
# create map
map_clusters = folium.Map(location=[centroid_Lat,centroid_Lon], zoom_start=5)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(cities_merged_selected['Latitude'], cities_merged_selected['Longitude'], cities_merged_selected['City'], cities_merged_selected['Cluster_Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
